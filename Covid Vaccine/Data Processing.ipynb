# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('country_vaccinations.csv')

# %%
df.head()
# Out:
#        country iso_code        date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG  2021-02-22                 0.0                0.0
# 1  Afghanistan      AFG  2021-02-23                 NaN                NaN
# 2  Afghanistan      AFG  2021-02-24                 NaN                NaN
# 3  Afghanistan      AFG  2021-02-25                 NaN                NaN
# 4  Afghanistan      AFG  2021-02-26                 NaN                NaN
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
# 1                      NaN                     NaN              1367.0
# 2                      NaN                     NaN              1367.0
# 3                      NaN                     NaN              1367.0
# 4                      NaN                     NaN              1367.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# ...

# %%
df.shape
# Out:
# (9465, 15)

# %%
df.country.nunique()
# Out:
# 162

# %%
df.groupby('country').max()
# Out:
#              iso_code        date  total_vaccinations  people_vaccinated  \
# country
# Afghanistan       AFG  2021-03-16             54000.0            54000.0
# Albania           ALB  2021-03-31            119321.0             6073.0
# Algeria           DZA  2021-02-19             75000.0                NaN
# Andorra           AND  2021-03-19              9288.0             7098.0
# Angola            AGO  2021-03-29            130750.0           130750.0
# ...               ...         ...                 ...                ...
# Uruguay           URY  2021-04-02            772120.0           704237.0
# Venezuela         VEN  2021-03-26             14223.0            14223.0
# Vietnam           VNM  2021-03-30             48256.0            48256.0
# Wales        OWID_WLS  2021-03-31           1893423.0          1443885.0
# Zimbabwe          ZWE  2021-04-02            124753.0           103815.0
#
#              people_fully_vaccinated  daily_vaccinations_raw  \
# country
# ...

# %%
df_country = df.groupby('country').max().reset_index()

# %%
df_country.head()
# Out:
#        country iso_code        date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG  2021-03-16             54000.0            54000.0
# 1      Albania      ALB  2021-03-31            119321.0             6073.0
# 2      Algeria      DZA  2021-02-19             75000.0                NaN
# 3      Andorra      AND  2021-03-19              9288.0             7098.0
# 4       Angola      AGO  2021-03-29            130750.0           130750.0
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN              2862.0
# 1                    655.0                  5356.0              9333.0
# 2                      NaN                    30.0              3748.0
# 3                   1265.0                     NaN               679.0
# 4                      NaN                     NaN              8057.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# ...

# %%
idx = df.groupby(['country'])['date'].transform(max) == df['date']

# %%
df_latest = df[idx]

# %%
df_latest.reset_index(drop = True)
# Out:
#          country  iso_code        date  total_vaccinations  people_vaccinated  \
# 0    Afghanistan       AFG  2021-03-16             54000.0            54000.0
# 1        Albania       ALB  2021-03-31            119321.0                NaN
# 2        Algeria       DZA  2021-02-19             75000.0                NaN
# 3        Andorra       AND  2021-03-19              9288.0                NaN
# 4         Angola       AGO  2021-03-29            130750.0           130750.0
# ..           ...       ...         ...                 ...                ...
# 157      Uruguay       URY  2021-04-02            772120.0           704237.0
# 158    Venezuela       VEN  2021-03-26             14223.0            14223.0
# 159      Vietnam       VNM  2021-03-30             48256.0            48256.0
# 160        Wales  OWID_WLS  2021-03-31           1893423.0          1443885.0
# 161     Zimbabwe       ZWE  2021-04-02            124753.0           103815.0
#
# ...

# %%
df_latest.to_csv('country_vaccinations_latest_03042021.csv', index = False )

# %%
df_latest[df['country'].isin(['United Kingdom', 'England', 'Northern Ireland','Scotland','Wales'])]
# Out:
# <ipython-input-45-387e2cc48637>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_latest[df['country'].isin(['United Kingdom', 'England', 'Northern Ireland','Scotland','Wales'])]
#                country  iso_code        date  total_vaccinations  \
# 2672           England  OWID_ENG  2021-04-01          30507732.0
# 6385  Northern Ireland  OWID_NIR  2021-04-01            918459.0
# 7685          Scotland  OWID_SCT  2021-04-01           2930288.0
# 9110    United Kingdom       GBR  2021-04-01          36249902.0
# 9420             Wales  OWID_WLS  2021-03-31           1893423.0
#
#       people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# 2672         26576629.0                3931103.0                534408.0
# 6385           765005.0                 153454.0                 16693.0
# 7685          2515748.0                 414540.0                 37899.0
# ...

# %%
df_latest.describe()
# Out:
#        total_vaccinations  people_vaccinated  people_fully_vaccinated  \
# count        1.610000e+02       1.410000e+02             9.000000e+01
# mean         4.182161e+06       2.708699e+06             1.566068e+06
# std          1.762002e+07       1.069360e+07             6.268501e+06
# min          9.910000e+02       9.910000e+02             2.000000e+00
# 25%          4.073200e+04       3.300000e+04             2.617000e+04
# 50%          2.411270e+05       1.617710e+05             1.629895e+05
# 75%          1.101528e+06       9.615590e+05             6.726302e+05
# max          1.576065e+08       1.018048e+08             5.798478e+07
#
#        daily_vaccinations_raw  daily_vaccinations  \
# count            8.900000e+01        1.600000e+02
# mean             2.341907e+05        1.040996e+05
# std              9.669854e+05        5.030913e+05
# min              7.000000e+00        1.400000e+01
# 25%              5.224000e+03        1.284250e+03
# ...

# %%
df_latest[df_latest['people_fully_vaccinated_per_hundred'] == df_latest['people_fully_vaccinated_per_hundred'].max()]
# Out:
#         country iso_code        date  total_vaccinations  people_vaccinated  \
# 3335  Gibraltar      GIB  2021-04-02             60907.0            32293.0
#
#       people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 3335                  28614.0                   642.0               624.0
#
#       total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 3335                          180.78                          95.85
#
#       people_fully_vaccinated_per_hundred  daily_vaccinations_per_million  \
# 3335                                84.93                         18521.0
#
#              vaccines              source_name  \
# 3335  Pfizer/BioNTech  Government of Gibraltar
#
#                                          source_website
# 3335  https://twitter.com/GibraltarGov/status/137792...
