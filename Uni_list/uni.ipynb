# %%
import numpy as np
import pandas as pd
import requests
from bs4 import BeautifulSoup
import os

# %%
with open("Search Master's Programmes Worldwide - MastersPortal.com.html","r", encoding="UTF-8") as file:
    soup = BeautifulSoup(file, 'lxml')

# %%
soup.find_all('div', class_='TrackingLinkedList').find_all('a', class_=)
# Out:
# <div class="TrackingLinkedList" data-list-type="study" data-start="0" data-type="rslts" id="StudySearchResultsStudies"> <a class="Result master ClickThrough premium js-Study StudyCard" data-id="8984" data-position="1" data-premium-type="p" data-proxy-url="https://1cna6fszvk.execute-api.eu-west-1.amazonaws.com/prod?position=1&amp;listing=p&amp;id=8984&amp;enhanced=true&amp;total=34&amp;title=Computing+Science&amp;duid=7e89e8d8-5899-4e4f-b90c-0e7b76438725&amp;sid=67f39984-a122-494c-bc23-defd9dcc6659&amp;redirectURL=https%3A%2F%2Fwww.mastersportal.com%3A%2Fstudies%2F8984%2F&amp;ip=172.30.7.86&amp;url=https%3A%2F%2Fwww.mastersportal.com%2Fsearch%2F%23q%3Dci-1%7Cdi-282%7Clv-master%7Ctc-EUR&amp;page=Search%2520Master%27s%2520Programmes%2520Worldwide%2520-%2520MastersPortal.com&amp;refr=&amp;res=1440x900&amp;uid=null&amp;ua=Mozilla%252F5.0%2520%28Windows%2520NT%252010.0%253B%2520Win64%253B%2520x64%29%2520AppleWebKit%252F537.36%2520%28KHTML%252C%2520like%2520Gecko%29%2520Chrome%252F86.0.4240
# ...
